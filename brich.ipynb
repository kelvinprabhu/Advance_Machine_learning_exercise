# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
df = pd.read_csv(r'DATASETS\classification\birch_case_study_dataset - birch_case_study_dataset.csv')

# %%
df.head()
# Out:
#    ID    X    Y    Z Category
# 0   1  1.5  1.7  1.3        B
# 1   2  2.0  2.4  2.6        C
# 2   3  2.5  3.1  3.9        A
# 3   4  3.0  3.8  5.2        B
# 4   5  3.5  1.0  6.5        C

# %%
from sklearn.cluster import Birch
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
X = df.drop(['Category','ID'], axis=1)
df['Category'].unique()
# Out:
# array(['B', 'C', 'A'], dtype=object)

# %%
br = Birch(n_clusters=3)
br.fit(X)
X['birch_labels'] = br.labels_
X['birch_labels'].value_counts()
# Out:
# birch_labels
# 0    61
# 1    20
# 2    19
# Name: count, dtype: int64

# %%
X['birch_labels'].value_counts() , df['Category'].value_counts()
# Out:
# (birch_labels
#  0    61
#  1    20
#  2    19
#  Name: count, dtype: int64,
#  Category
#  1    34
#  2    33
#  0    33
#  Name: count, dtype: int64)

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
X['kmeans_labels'] = kmeans.labels_
X['kmeans_labels'].value_counts()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# kmeans_labels
# 0    44
# 2    32
# 1    24
# Name: count, dtype: int64

# %%
X['birch_labels'] = X['birch_labels'].map({0:'A',1:'B',2:'C'})
X['kmeans_labels'] = X['kmeans_labels'].map({0:'A',1:'B',2:'C'})

# %%
sns.pairplot(df, hue='Category')

# %%
sns.kdeplot(x=df['X'], y=df['Y'], cmap='viridis', shade=True, cbar=True)
sns.kdeplot(x=df['X'], y=df['Z'], cmap='viridis', shade=True, cbar=True)
sns.kdeplot(x=df['Y'], y=df['Z'], cmap='viridis', shade=True, cbar=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22300\3724850819.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df['X'], y=df['Y'], cmap='viridis', shade=True, cbar=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22300\3724850819.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df['X'], y=df['Z'], cmap='viridis', shade=True, cbar=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22300\3724850819.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df['Y'], y=df['Z'], cmap='viridis', shade=True, cbar=True)
# <Axes: xlabel='X', ylabel='Y'>

# %%
sns.kdeplot(data=X,multiple='stack',cbar=True)
# Out:
# <Axes: ylabel='Density'>

# %%
from mpl_toolkits.mplot3d import Axes3D

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Category'] = le.fit_transform(df['Category'])
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['X'], df['Y'], df['Z'], c=df['Category'])

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.show()

# %%
X.head() , df.head()
# Out:
# (     X    Y    Z birch_labels kmeans_labels
#  0  1.5  1.7  1.3            C             B
#  1  2.0  2.4  2.6            C             B
#  2  2.5  3.1  3.9            A             B
#  3  3.0  3.8  5.2            A             A
#  4  3.5  1.0  6.5            A             A,
#     ID    X    Y    Z  Category  birch_labels
#  0   1  1.5  1.7  1.3         1             2
#  1   2  2.0  2.4  2.6         2             2
#  2   3  2.5  3.1  3.9         0             0
#  3   4  3.0  3.8  5.2         1             0
#  4   5  3.5  1.0  6.5         2             0)

# %%
X['Category'] = df['Category']
X['Category'] = X['Category'].map({0:'A',1:'B',2:'C'})
# Out:
#      X    Y    Z birch_labels kmeans_labels Category
# 0  1.5  1.7  1.3            C             B        B
# 1  2.0  2.4  2.6            C             B        C
# 2  2.5  3.1  3.9            A             B        A
# 3  3.0  3.8  5.2            A             A        B
# 4  3.5  1.0  6.5            A             A        C

# %%
X.head()
# Out:
#      X    Y    Z kmeans_labels Category  birch_labels
# 0  1.5  1.7  1.3             B        B             2
# 1  2.0  2.4  2.6             B        C             2
# 2  2.5  3.1  3.9             B        A             0
# 3  3.0  3.8  5.2             A        B             0
# 4  3.5  1.0  6.5             A        C             0

# %%
df = pd.read_csv(r'DATASETS\classification\basic1 - basic1.csv')
df.head()
# Out:
#             x           y  color
# 0   79.408289  152.834424      0
# 1   98.046263  186.910700      0
# 2  240.578979   48.473684      1
# 3  109.687183  277.945769      0
# 4  249.626082  229.753352      1

# %%
sns.kdeplot(x=df['x'], y=df['y'], cmap='viridis', fill=True, cbar=True)
sns.pairplot(df, hue='color')
# Out:
# <Axes: xlabel='y', ylabel='Density'>

# %%
sns.kdeplot(data=df, multiple='stack', cbar=True)
# Out:
# <Axes: ylabel='Density'>

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = df.drop('color', axis=1)
X = sc.fit_transform(X)
X = pd.DataFrame(X, columns=['x','y'])
sns.kdeplot(X)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(df['x'])
sns.kdeplot(df['y'])
# Out:
# <Axes: xlabel='x', ylabel='Density'>
